# %% [markdown]
# # Wrangle

# %%
import pandas as pd

# %%
##### missile_data sheet names ######
'''
'Missile Defense Engagements',
'Locations',
'Interceptors',
'Interceptor Systems',
'Targets'
'''

# load all sheets in the file
missile_data = pd.read_excel('CNS Global Missile Defense Engagement.xlsx', 
          index_col=0, 
          sheet_name=None)

# %%
mde = missile_data['Missile Defense Engagements']
mde.head()
# Out:
#    Date_Of_Test         Launch_Time Date_Entered/Updated Country  \
# ID
# 1    1999-10-02                 NaT           2019-01-16     USA
# 2    2000-01-18 2000-01-18 22:40:00           2019-01-16     USA
# 3    2000-07-08                 NaT           2019-01-16     USA
# 4    2001-07-14                 NaT           2019-01-16     USA
# 5    2001-12-03                 NaT           2019-01-18     USA
#
#    Launch_Authority              Missile_Name                Target_Missile  \
# ID
# 1              BMDO  Ground-Based Interceptor  Long Range Ballistic Missile
# 2              BMDO  Ground-Based Interceptor  Long Range Ballistic Missile
# 3              BMDO  Ground-Based Interceptor  Long Range Ballistic Missile
# 4              BMDO  Ground-Based Interceptor  Long Range Ballistic Missile
# 5              BMDO  Ground-Based Interceptor  Long Range Ballistic Missile
#
#     Type_of_Launch Launch_Location  Number_of_Interceptors  \
# ID
# ...

# %%
mde.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365 entries, 1 to 371
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date_Of_Test                365 non-null    datetime64[ns]
#  1   Launch_Time                 97 non-null     datetime64[ns]
#  2   Date_Entered/Updated        365 non-null    datetime64[ns]
#  3   Country                     365 non-null    object
#  4   Launch_Authority            365 non-null    object
#  5   Missile_Name                365 non-null    object
#  6   Target_Missile              365 non-null    object
#  7   Type_of_Launch              365 non-null    object
#  8   Launch_Location             365 non-null    object
#  9   Number_of_Interceptors      218 non-null    float64
#  10  Target_Launch_Location      360 non-null    object
#  11  Intercept_Attempt_Outcome   221 non-null    object
#  12  Claimed_Intercept_Outcome   144 non-null    object
# ...

# %%
mde.describe()
# Out:
#                         Date_Of_Test                    Launch_Time  \
# count                            365                             97
# mean   2008-01-09 17:13:38.630137088  2001-08-22 18:29:11.752577536
# min              1960-12-08 00:00:00            1991-01-20 18:43:00
# 25%              2001-10-19 00:00:00            1991-01-26 00:28:00
# 50%              2012-10-24 00:00:00            2003-03-20 09:24:00
# 75%              2017-06-21 00:00:00            2011-04-15 06:52:00
# max              2019-11-06 00:00:00            2019-03-27 05:39:00
# std                              NaN                            NaN
#
#                 Date_Entered/Updated  Number_of_Interceptors
# count                            365              218.000000
# mean   2019-05-26 21:26:08.219177984                1.357798
# min              2018-06-14 00:00:00                1.000000
# 25%              2019-03-27 00:00:00                1.000000
# ...
